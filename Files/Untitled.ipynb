# %%
import numpy as np
import pandas as pd
import xlrd
import csv

data = pd.read_excel("Console Form (Responses).xlsx")
data
# Out:
#                   Timestamp                Email Address        Full Name  \
# 0   2020-05-22 11:03:01.149          romak7438@gmail.com      Roma kumari
# 1   2020-05-22 11:05:37.883       wasim7raja10@gmail.com       Wasim Raja
# 2   2020-05-22 11:11:54.523         drstar8877@gmail.com     Aditya kumar
# 3   2020-05-22 11:15:43.312  manitoshraj.mj121@gmail.com    Manitosh Paul
# 4   2020-05-22 11:16:51.031     deveshtiwary19@gmail.com    Devesh Tiwary
# ..                      ...                          ...              ...
# 316 2020-05-29 17:14:07.654    monalishadas760@gmail.com    Monalisha Das
# 317 2020-05-29 20:10:40.193      biswaslobendu@gmail.com   Lobendu Biswas
# 318 2020-05-30 16:33:05.342       saharohit158@gmail.com       Rohit Saha
# 319 2020-05-31 12:25:48.978     sinhashreyaa18@gmail.com     Shreya Sinha
# 320 2020-05-31 20:25:03.013   shubham.heroo333@gmail.com  Shubham Jaiswal
#
#      Contact Number(without country code)  Whatsapp Number  Gender  \
# ...
